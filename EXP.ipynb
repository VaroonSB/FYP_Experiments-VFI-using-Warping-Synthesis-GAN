# %%
import h5py
filename = './model_weights/model_weights.hdf5'

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]
    b_group_key = list(f.keys())[1]
    # Get the data
    data = list(f[a_group_key])
    print('\n')
    print('\n')
    print(data)
    print('\n')
    print('\n')


    # data1 = list(f[b_group_key])
    # print('\n')
    # print('\n')
    # print(data1)
    # print('\n')
    # print('\n')
# Out:
# Keys: <KeysViewHDF5 ['model_weights', 'optimizer_weights']>
#
#
#
#
# ['batch_normalization', 'batch_normalization_1', 'batch_normalization_10', 'batch_normalization_11', 'batch_normalization_12', 'batch_normalization_13', 'batch_normalization_14', 'batch_normalization_15', 'batch_normalization_16', 'batch_normalization_17', 'batch_normalization_18', 'batch_normalization_19', 'batch_normalization_2', 'batch_normalization_20', 'batch_normalization_21', 'batch_normalization_3', 'batch_normalization_4', 'batch_normalization_5', 'batch_normalization_6', 'batch_normalization_7', 'batch_normalization_8', 'batch_normalization_9', 'concatenate', 'concatenate_1', 'concatenate_2', 'concatenate_3', 'concatenate_4', 'conv2d', 'conv2d_1', 'conv2d_10', 'conv2d_11', 'conv2d_12', 'conv2d_13', 'conv2d_14', 'conv2d_15', 'conv2d_16', 'conv2d_17', 'conv2d_18', 'conv2d_19', 'conv2d_2', 'conv2d_20', 'conv2d_21', 'conv2d_22', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_7', 'conv2d_8', 'conv2d_9', 'input_1', 'max_pooling2d', 'max_pooling2d_1', 'max_pooling2d_2', 'max_pooling2d_3', 'max_pooling2d_4', 'up_sampling2d', 'up_sampling2d_1', 'up_sampling2d_2', 'up_sampling2d_3', 'up_sampling2d_4']

# %%
from core.networks import UNET
import tensorflow.keras.backend as K
K.set_image_data_format('channels_first')
model = UNET((6,256,512), 'relu')

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 6, 256, 512) 0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 256, 512) 1760        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 256, 512) 2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 256, 512) 9248        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 256, 512) 2048        conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 128, 256) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 128, 256) 18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 128, 256) 1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 128, 256) 36928       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 128, 256) 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 64, 128) 73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 64, 128) 512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 64, 128) 147584      batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 64, 128) 512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 128, 32, 64)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 32, 64)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 256, 32, 64)  256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 256, 32, 64)  590080      batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 256, 32, 64)  256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 256, 16, 32)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 512, 16, 32)  1180160     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 512, 16, 32)  128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 512, 16, 32)  2359808     batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 512, 16, 32)  128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 512, 8, 16)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 512, 8, 16)   2359808     max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 512, 8, 16)   64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 512, 8, 16)   2359808     batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 512, 8, 16)   64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 512, 16, 32)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1024, 16, 32) 0           up_sampling2d_5[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 512, 16, 32)  4719104     concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 512, 16, 32)  128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 512, 16, 32)  2359808     batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 512, 16, 32)  128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 512, 32, 64)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 768, 32, 64)  0           up_sampling2d_6[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 32, 64)  1769728     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 32, 64)  256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 32, 64)  590080      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256, 32, 64)  256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 64, 128) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 384, 64, 128) 0           up_sampling2d_7[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 64, 128) 442496      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 64, 128) 512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 64, 128) 147584      batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 64, 128) 512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 192, 128, 256 0           up_sampling2d_8[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 128, 256) 110656      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 128, 256) 1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 128, 256) 36928       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 128, 256) 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 64, 256, 512) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 96, 256, 512) 0           up_sampling2d_9[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 256, 512) 27680       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 256, 512) 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 256, 512) 9248        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 256, 512) 2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 3, 256, 512)  99          batch_normalization_43[0][0]
# ==================================================================================================
# Total params: 19,662,115
# Trainable params: 19,654,115
# Non-trainable params: 8,000
# __________________________________________________________________________________________________

# %%
import os
import cv2 
from PIL import Image 
  
# Checking the current directory path
# print(os.getcwd()) 
  
# Folder which contains all the images
# from which video is to be generated
os.chdir("D:\Fusion\input")  
path = "D:\Fusion\input"
  
mean_height = 0
mean_width = 0
  
num_of_images = len(os.listdir('.'))
# print(num_of_images)
  
for file in os.listdir('.'):
    im = Image.open(os.path.join(path, file))
    width, height = im.size
    mean_width += width
    mean_height += height
    # im.show()   # uncomment this for displaying the image
  
# Finding the mean height and width of all images.
# This is required because the video frame needs
# to be set with same width and height. Otherwise
# images not equal to that width height will not get 
# embedded into the video
mean_width = int(mean_width / num_of_images)
mean_height = int(mean_height / num_of_images)
  
# print(mean_height)
# print(mean_width)
  
# Resizing of the images to give
# them same width and height 
for file in os.listdir('.'):
    if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png"):
        # opening image using PIL Image
        im = Image.open(os.path.join(path, file)) 
   
        # im.size includes the height and width of image
        width, height = im.size   
        print(width, height)
  
        # resizing 
        imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS) 
        imResize.save( file, 'JPEG', quality = 95) # setting quality
        # printing each resized image name
        print(im.filename.split('\\')[-1], " is resized") 
  
  
# Video Generating function
def generate_video():
    image_folder = '.' # make sure to use your folder
    video_name = 'mygeneratedvideo.avi'
    os.chdir("D:\Fusion\input")
      
    images = [img for img in os.listdir(image_folder)
              if img.endswith(".jpg") or
                 img.endswith(".jpeg") or
                 img.endswith("png")]
     
    # Array images should only consider
    # the image files ignoring others if any
    print(images) 
  
    frame = cv2.imread(os.path.join(image_folder, images[0]))
  
    # setting the frame width, height width
    # the width, height of first image
    height, width, layers = frame.shape  
  
    video = cv2.VideoWriter(video_name, 0, 1, (width, height)) 
  
    # Appending the images to the video one by one
    for image in images: 
        video.write(cv2.imread(os.path.join(image_folder, image))) 
      
    # Deallocating memories taken for window creation
    cv2.destroyAllWindows() 
    video.release()  # releasing the video generated
  
  
# Calling the generate_video function
generate_video()
# Out:
# 957 856
# 000350.png  is resized
# 957 856
# 000351.png  is resized
# 957 856
# 000352.png  is resized
# 957 856
# 000353.png  is resized
# 957 856
# 000354.png  is resized
# 957 856
# 000355.png  is resized
# 957 856
# 000356.png  is resized
# ['000350.png', '000351.png', '000352.png', '000353.png', '000354.png', '000355.png', '000356.png']

# %%
import h5py
hf = h5py.File('./data/dataset.hdf5', 'r')

for i in hf.keys():
  print(i)

# x_train = hf.get('x_train')
# y_train = hf.get('y_train')
# x_valid = hf.get('x_valid')
# y_valid = hf.get('y_valid')

# print(x_train)
# print(y_train)
# print(x_valid)
# print(y_valid)
# Out:
# x_test
# x_train
# x_valid
# y_test
# y_train
# y_valid

# %%
import sys
import os
import cv2
import tensorflow.keras.backend as K
import numpy as np
from numpy import asarray
from core.networks import UNET
from PIL import Image as im
K.set_image_data_format('channels_first')
os.environ['KERAS_BACKEND'] = "tensorflow"
vid_arr = np.zeros(shape=(2, 256, 512, 3), dtype="uint8")
image1 = im.open('./000350.png')
image2 = im.open('./000352.png')
vid_arr[0] = cv2.resize(asarray(image1), (512, 256))
vid_arr[1] = cv2.resize(asarray(image2), (512, 256))

model = UNET((6, 256, 512))
model.load_weights('./model_weights_for 512x256 5 ep/model_weights.hdf5')

pred = model.predict(np.expand_dims(np.transpose(np.concatenate((vid_arr[0], vid_arr[1]), axis=2)/255., (2,0,1)), axis=0))
res = (np.transpose(pred[0], (1, 2, 0))*255).astype("uint8")
img = im.fromarray(res)
img.save('./out.png')

# print(len(res))

# %%
import cv2
from PIL import Image as im
import tensorflow.keras.backend as K
K.set_image_data_format('channels_first')
os.environ['KERAS_BACKEND'] = "tensorflow"
from math import log10, sqrt
import numpy as np
# def PSNR(y_true, y_pred):
#     max_pixel = 1.0
#     return (10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true), axis=-1)))) / 2.303

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):  # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

# %%
gt = im.open('./GT.png')
out = im.open('./out.png')
result = gt.resize((512, 256))
result.save('./resized.png')

# %%
predicted = cv2.imread('./out.png')
ori = cv2.imread('./resized.png')
print(PSNR(ori, predicted))
# Out:
# 30.705872857479513
